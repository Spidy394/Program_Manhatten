# %% [markdown]
# <a href="https://colab.research.google.com/github/Spidy394/Program_Manhatten/blob/main/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Concatenation

# %% [markdown]
# ## 1. Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##2. Import all the necessary datasets

# %%
april = pd.read_excel('Book_Sales_April.xlsx')
may = pd.read_excel('Book_Sales_May.xlsx')
june = pd.read_excel('Book_Sales_June.xlsx')

# %%
april.head()
# Out:
#    Purchase ID  Customer ID                Book  Audience        Genre  Price  \
# 0          401          101   Unicorns Are Cool  Children      Fiction   4.99
# 1          402          101     I Love Unicorns  Children      Fiction   5.99
# 2          403          102   All About Turtles     Teens  Non-Fiction  19.99
# 3          404          102    All About Whales     Teens  Non-Fiction  19.99
# 4          405          102  All About Dolphins     Teens  Non-Fiction  19.99
#
#    Book Rating Purchase Location Purchase Date
# 0          3.6            Online    2023-04-01
# 1          4.1            Online    2023-04-01
# 2          3.3         In Person    2023-04-02
# 3          2.5         In Person    2023-04-02
# 4          4.2         In Person    2023-04-02

# %%
print(april['Purchase Date'].max())
print(april['Purchase Date'].min())
# Out:
# 2023-04-26 00:00:00
# 2023-04-01 00:00:00

# %%
may.head()
# Out:
#    Purchase ID  Customer ID                Book  Audience        Genre  Price  \
# 0          414          109    The Concert Hall    Adults      Fiction  22.72
# 1          415          110      Space and Time    Adults      Fiction  21.58
# 2          416          101            Rainbows  Children      Fiction  10.25
# 3          417          104  The Speed of Light    Adults      Fiction  20.32
# 4          418          106      Real Dinosaurs  Children  Non-Fiction   9.99
#
#    Book Rating Purchase Location Purchase Date
# 0          4.7            Online    2023-05-01
# 1          3.7         In Person    2023-05-04
# 2          4.7            Online    2023-05-04
# 3          4.1         In Person    2023-05-04
# 4          3.4         In Person    2023-05-04

# %%
print(may['Purchase Date'].max())
print(may['Purchase Date'].min())
# Out:
# 2023-05-26 00:00:00
# 2023-05-01 00:00:00

# %%
june.head()
# Out:
#    Purchase ID  Customer ID                          Book  Audience  \
# 0          432          117                   Blue Waters    Adults
# 1          433          118                      The Cave    Adults
# 2          434          106       Best Dinosaur Book Ever  Children
# 3          435          103  Peter Penn: The Untold Story    Adults
# 4          436          101         Everything is Amazing  Children
#
#          Genre  Price  Book Rating Purchase Location Purchase Date
# 0      Fiction  23.98          2.6            Online    2023-06-05
# 1      Fiction  24.99          4.7            Online    2023-06-07
# 2  Non-Fiction  10.49          4.7         In Person    2023-06-08
# 3  Non-Fiction  27.90          4.8         In Person    2023-06-08
# 4      Fiction   4.99          3.9         In Person    2023-06-08

# %%
print(june['Purchase Date'].max())
print(june['Purchase Date'].min())
# Out:
# 2023-06-27 00:00:00
# 2023-06-05 00:00:00

# %% [markdown]
# ##3. Row wise concatenation of april and may

# %%
df_apr_may = pd.concat([april , may] , axis = 0 , ignore_index=True)
# Out:
#     Purchase ID  Customer ID                        Book  Audience  \
# 0           401          101           Unicorns Are Cool  Children
# 1           402          101             I Love Unicorns  Children
# 2           403          102           All About Turtles     Teens
# 3           404          102            All About Whales     Teens
# 4           405          102          All About Dolphins     Teens
# 5           406          103      Brooke Reeder's Memoir    Adults
# 6           407          104                The Last Day    Adults
# 7           408          105                  Summer Sun    Adults
# 8           409          101          Glitter Everything  Children
# 9           410          102         All About the Ocean     Teens
# 10          411          106          Dinosaurs Are Cool  Children
# 11          412          107  Intro to Jupyter Notebooks    Adults
# 12          413          108             The Moon Smiles  Children
# ...

# %%
df_apr_may.head()
# Out:
#    Purchase ID  Customer ID                Book  Audience        Genre  Price  \
# 0          401          101   Unicorns Are Cool  Children      Fiction   4.99
# 1          402          101     I Love Unicorns  Children      Fiction   5.99
# 2          403          102   All About Turtles     Teens  Non-Fiction  19.99
# 3          404          102    All About Whales     Teens  Non-Fiction  19.99
# 4          405          102  All About Dolphins     Teens  Non-Fiction  19.99
#
#    Book Rating Purchase Location Purchase Date
# 0          3.6            Online    2023-04-01
# 1          4.1            Online    2023-04-01
# 2          3.3         In Person    2023-04-02
# 3          2.5         In Person    2023-04-02
# 4          4.2         In Person    2023-04-02

# %%
df_apr_may.tail()
# Out:
#     Purchase ID  Customer ID                   Book  Audience        Genre  \
# 26          427          106    Which Dino is Best?  Children  Non-Fiction
# 27          428          101  Unicorns Are The Best  Children      Fiction
# 28          429          111   Star Battles: Part 3     Teens      Fiction
# 29          430          112   Our Wonderous Planet     Teens  Non-Fiction
# 30          431          116            Who's There    Adults      Fiction
#
#     Price  Book Rating Purchase Location Purchase Date
# 26   8.99          2.6         In Person    2023-05-22
# 27   4.99          2.3            Online    2023-05-23
# 28  13.50          4.4            Online    2023-05-24
# 29  17.75          4.5         In Person    2023-05-25
# 30  24.99          2.1            Online    2023-05-26

# %% [markdown]
# ##4. Row wise concatenation of april, may and june

# %%
df_apr_may_june = pd.concat([df_apr_may , june] , axis = 0 , ignore_index=True)

# %%
df_apr_may_june.shape
# Out:
# (50, 9)

# %%
df_apr_may_june.iloc[31,:]
# Out:
# Purchase ID                          432
# Customer ID                          117
# Book                         Blue Waters
# Audience                          Adults
# Genre                            Fiction
# Price                              23.98
# Book Rating                          2.6
# Purchase Location                 Online
# Purchase Date        2023-06-05 00:00:00
# Name: 31, dtype: object

# %%
df_apr_may_june.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Purchase ID        50 non-null     int64
#  1   Customer ID        50 non-null     int64
#  2   Book               50 non-null     object
#  3   Audience           50 non-null     object
#  4   Genre              50 non-null     object
#  5   Price              50 non-null     float64
#  6   Book Rating        50 non-null     float64
#  7   Purchase Location  50 non-null     object
#  8   Purchase Date      50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.6+ KB

# %%
df_apr_may_june['Genre'].value_counts()
# Out:
# Genre
# Fiction        31
# Non-Fiction    19
# Name: count, dtype: int64

# %%
sns.barplot(df_apr_may_june['Audience'].value_counts())
# Out:
# <Axes: xlabel='Audience', ylabel='count'>

# %% [markdown]
# #2. Combining Data

# %%
calendar = pd.read_csv('calendar.csv')
dictionary = pd.read_csv('data_dictionary.csv')
inventory = pd.read_csv('inventory.csv')
products = pd.read_csv('products.csv')
sales = pd.read_csv('sales.csv')
stores = pd.read_csv('stores.csv')

# %%
dictionary
# Out:
#         Table             Field  \
# 0    Products        Product_ID
# 1    Products      Product_Name
# 2    Products  Product_Category
# 3    Products      Product_Cost
# 4    Products     Product_Price
# 5   Inventory          Store_ID
# 6   Inventory        Product_ID
# 7   Inventory     Stock_On_Hand
# 8      Stores          Store_ID
# 9      Stores        Store_Name
# 10     Stores        Store_City
# 11     Stores    Store_Location
# 12     Stores   Store_Open_Date
# 13      Sales           Sale_ID
# 14      Sales              Date
# 15      Sales          Store_ID
# 16      Sales        Product_ID
# 17      Sales             Units
# 18   Calendar              Date
#
#                                           Description
# 0                                          Product ID
# 1                                        Product name
# 2                                    Product Category
# 3                                 Product cost ($USD)
# ...

# %%
sales.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units
# 0        1  2022-01-01        24           4    1.0
# 1        2  2022-01-01        28           1    1.0
# 2        3  2022-01-01         6           8    1.0
# 3        4  2022-01-01        48           7    1.0
# 4        5  2022-01-01        44          18    1.0

# %%
products.head()
# Out:
#    Product_ID      Product_Name Product_Category Product_Cost Product_Price
# 0           1     Action Figure             Toys       $9.99        $15.99
# 1           2    Animal Figures             Toys       $9.99        $12.99
# 2           3   Barrel O' Slime     Art & Crafts       $1.99         $3.99
# 3           4  Chutes & Ladders            Games       $9.99        $12.99
# 4           5  Classic Dominoes            Games       $7.99         $9.99

# %%
stores.head()
# Out:
#    Store_ID                Store_Name   Store_City Store_Location  \
# 0         1  Maven Toys Guadalajara 1  Guadalajara    Residential
# 1         2    Maven Toys Monterrey 1    Monterrey    Residential
# 2         3  Maven Toys Guadalajara 2  Guadalajara     Commercial
# 3         4     Maven Toys Saltillo 1     Saltillo       Downtown
# 4         5       Maven Toys La Paz 1       La Paz       Downtown
#
#   Store_Open_Date
# 0      1992-09-18
# 1      1995-04-27
# 2      1999-12-27
# 3      2000-01-01
# 4      2001-05-31

# %%
inventory.head()
# Out:
#    Store_ID  Product_ID  Stock_On_Hand
# 0         1           1             27
# 1         1           2              0
# 2         1           3             32
# 3         1           4              6
# 4         1           5              0

# %%
sales_products = pd.merge(sales, products, how='inner', on='Product_ID')

# %%
sales_products.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4    1.0  Chutes & Ladders
# 1        2  2022-01-01        28           1    1.0     Action Figure
# 2        3  2022-01-01         6           8    1.0     Deck Of Cards
# 3        4  2022-01-01        48           7    1.0          Dart Gun
# 4        5  2022-01-01        44          18    1.0       Lego Bricks
#
#     Product_Category Product_Cost Product_Price
# 0              Games       $9.99        $12.99
# 1               Toys       $9.99        $15.99
# 2              Games       $3.99         $6.99
# 3  Sports & Outdoors      $11.99        $15.99
# 4               Toys      $34.99        $39.99

# %%
sales_products_stores = pd.merge(sales_products, stores, how='inner', on='Store_ID')

# %%
sales_products_stores.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4    1.0  Chutes & Ladders
# 1        2  2022-01-01        28           1    1.0     Action Figure
# 2        3  2022-01-01         6           8    1.0     Deck Of Cards
# 3        4  2022-01-01        48           7    1.0          Dart Gun
# 4        5  2022-01-01        44          18    1.0       Lego Bricks
#
#     Product_Category Product_Cost Product_Price                   Store_Name  \
# 0              Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1               Toys       $9.99        $15.99           Maven Toys Puebla 2
# 2              Games       $3.99         $6.99         Maven Toys Mexicali 1
# 3  Sports & Outdoors      $11.99        $15.99         Maven Toys Saltillo 2
# 4               Toys      $34.99        $39.99           Maven Toys Puebla 3
#
#        Store_City Store_Location Store_Open_Date
# ...

# %%
sales_products_stores_inventory = pd.merge(sales_products_stores , inventory , how = 'inner' , on = ['Product_ID' , 'Store_ID'])

# %%
sales_products_stores_inventory.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4    1.0  Chutes & Ladders
# 1        2  2022-01-01        28           1    1.0     Action Figure
# 2        3  2022-01-01         6           8    1.0     Deck Of Cards
# 3        4  2022-01-01        48           7    1.0          Dart Gun
# 4        5  2022-01-01        44          18    1.0       Lego Bricks
#
#     Product_Category Product_Cost Product_Price                   Store_Name  \
# 0              Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1               Toys       $9.99        $15.99           Maven Toys Puebla 2
# 2              Games       $3.99         $6.99         Maven Toys Mexicali 1
# 3  Sports & Outdoors      $11.99        $15.99         Maven Toys Saltillo 2
# 4               Toys      $34.99        $39.99           Maven Toys Puebla 3
#
#        Store_City Store_Location Store_Open_Date  Stock_On_Hand
# ...

# %%
df = sales_products_stores_inventory

# %%
df.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4    1.0  Chutes & Ladders
# 1        2  2022-01-01        28           1    1.0     Action Figure
# 2        3  2022-01-01         6           8    1.0     Deck Of Cards
# 3        4  2022-01-01        48           7    1.0          Dart Gun
# 4        5  2022-01-01        44          18    1.0       Lego Bricks
#
#     Product_Category Product_Cost Product_Price                   Store_Name  \
# 0              Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1               Toys       $9.99        $15.99           Maven Toys Puebla 2
# 2              Games       $3.99         $6.99         Maven Toys Mexicali 1
# 3  Sports & Outdoors      $11.99        $15.99         Maven Toys Saltillo 2
# 4               Toys      $34.99        $39.99           Maven Toys Puebla 3
#
#        Store_City Store_Location Store_Open_Date  Stock_On_Hand
# ...

# %%
df['Store_Location'].value_counts()
# Out:
# Store_Location
# Downtown       160155
# Commercial      64420
# Residential     32955
# Airport         22876
# Name: count, dtype: int64

# %%
sns.barplot(df['Store_Location'].value_counts(), palette='coolwarm', edgecolor='black')

plt.title('Store Location Distribution')
plt.xlabel('Store Location')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (10,6))

sns.barplot(df['Product_Category'].value_counts() , palette = 'Set1' , edgecolor = 'black')

plt.title('Product Category Distribution')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.show()
