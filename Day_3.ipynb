# %% [markdown]
# <a href="https://colab.research.google.com/github/Spidy394/Program_Manhatten/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.

# %%
letter = 'I am currently undergoing the DS Roadmap'

# %%
len(letter)
# Out:
# 40

# %%
print(letter)
# Out:
# I am currently undergoing the DS Roadmap

# %%
letter = '12345-XYZP'

# %%
letter[0:5]
# Out:
# '12345'

# %%
goal = 'I want to be a junior data scientist'

# %%
goal.endswith('ist')
# Out:
# True

# %%
fruits = ['orange', 'pineapple', 'apple', 'grapes', 'lime']

# %%
type(fruits)
# Out:
# list

# %%
fruits[2]
# Out:
# 'apple'

# %%
fruits.append('banana')

# %%
fruits
# Out:
# ['orange', 'pineapple', 'apple', 'grapes', 'lime', 'banana']

# %%
fruits[0] = 'lichi'
fruits
# Out:
# ['lichi', 'pineapple', 'apple', 'grapes', 'lime', 'banana']

# %%
fruits[1] = 'apple'
fruits
# Out:
# ['lichi', 'apple', 'apple', 'grapes', 'lime', 'banana']

# %%
fruits = ('orange' , 'pineapple' , 'apple' , 'grapes' , 'lime')

# %%
type(fruits)
# Out:
# tuple

# %% [markdown]
# # 2.

# %%
import pandas as pd

# %%
Movies = pd.read_csv("Movies.csv")

# %%
Movies['imdb_score']
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       6.6
#        ...
# 3848    7.0
# 3849    6.3
# 3850    6.9
# 3851    6.4
# 3852    6.6
# Name: imdb_score, Length: 3853, dtype: float64

# %%
Movies['imdb_score'].max()
# Out:
# 9.3

# %%
Movies[Movies['imdb_score'] > 9.3]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []
#
# [0 rows x 28 columns]

# %%
Movies[Movies['imdb_score'] >= 9.3]
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 1795  Color  Frank Darabont                   199.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 1795                      0.0                   461.0  Jeffrey DeMunn
#
#       actor_1_facebook_likes       gross       genres  ...  \
# 1795                 11000.0  28341469.0  Crime|Drama  ...
#
#      num_user_for_reviews language  country  content_rating      budget  \
# 1795               4144.0  English      USA               R  25000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 1795      1994.0                  745.0        9.3          1.85
#
#      movie_facebook_likes
# 1795               108000
#
# [1 rows x 28 columns]

# %%
Movies.iloc[1795 , :]
# Out:
# color                                                                    Color
# director_name                                                   Frank Darabont
# num_critic_for_reviews                                                   199.0
# duration                                                                 142.0
# director_facebook_likes                                                    0.0
# actor_3_facebook_likes                                                   461.0
# actor_2_name                                                    Jeffrey DeMunn
# actor_1_facebook_likes                                                 11000.0
# gross                                                               28341469.0
# genres                                                             Crime|Drama
# actor_1_name                                                    Morgan Freeman
# movie_title                                          The Shawshank Redemption
# ...

# %%
Movies[Movies['imdb_score']<=1.6]
# Out:
#       color director_name  num_critic_for_reviews  duration  \
# 2540  Color    Jon M. Chu                    84.0     115.0
#
#       director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 2540                    209.0                    41.0  Sean Kingston
#
#       actor_1_facebook_likes       gross             genres  ...  \
# 2540                   569.0  73000942.0  Documentary|Music  ...
#
#      num_user_for_reviews language  country  content_rating      budget  \
# 2540                233.0  English      USA               G  13000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2540      2011.0                   69.0        1.6          1.85
#
#      movie_facebook_likes
# 2540                62000
#
# [1 rows x 28 columns]

# %%
Movies['imdb_score'].median()
# Out:
# 6.6

# %%
Movies['imdb_score'].mean()
# Out:
# np.float64(6.462886062808201)

# %%
Movies['imdb_score'].max()
# Out:
# 9.3

# %%
Movies['imdb_score'].min()
# Out:
# 1.6

# %%
Movies['imdb_score'].std()
# Out:
# 1.0538428796061452

# %%
Movies['imdb_score'].var()
# Out:
# 1.1105848148965725

# %%
import seaborn as sns

# %%
sns.histplot(Movies['imdb_score'] , color = 'red')
# Out:
# <Axes: xlabel='imdb_score', ylabel='Count'>

# %%
Movies[(Movies['imdb_score'] >= 6.7) & (Movies['imdb_score'] <= 7)]
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 2     Color        Sam Mendes                   602.0     148.0
# 9     Color       Zack Snyder                   673.0     183.0
# 11    Color      Marc Forster                   403.0     106.0
# 17    Color      Rob Marshall                   448.0     136.0
# 18    Color  Barry Sonnenfeld                   451.0     106.0
# ...     ...               ...                     ...       ...
# 3825  Color         E.L. Katz                   193.0      88.0
# 3838  Color     James Bidgood                     8.0      65.0
# 3845  Color   Olivier Assayas                    81.0     110.0
# 3848  Color     Shane Carruth                   143.0      77.0
# 3850  Color  Robert Rodriguez                    56.0      81.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 2                         0.0                   161.0       Rory Kinnear
# ...

# %%
sns.histplot(Movies['imdb_score'] , color = 'red', bins=10)
# Out:
# <Axes: xlabel='imdb_score', ylabel='Count'>

# %%
Movies[Movies['imdb_score'] <= 2.37]
# Out:
#       color           director_name  num_critic_for_reviews  duration  \
# 305   Color       Lawrence Guterman                    78.0      94.0
# 2019  Color         Jason Friedberg                   112.0      93.0
# 2085  Color         Jason Friedberg                   111.0      88.0
# 2111  Color               Bob Clark                    32.0      88.0
# 2127  Color                Uwe Boll                   148.0      94.0
# 2540  Color              Jon M. Chu                    84.0     115.0
# 2673  Color           Robert Iscove                    60.0      90.0
# 2931  Color      Vondie Curtis-Hall                    66.0     104.0
# 3049  Color        Don Michael Paul                    25.0      93.0
# 3064  Color               Alex Zamm                    12.0      95.0
# 3161  Color  Preston A. Whitmore II                    25.0      95.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(Movies['imdb_score'] , kde=True);
